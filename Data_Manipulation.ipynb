# %% [markdown]
# <a href="https://colab.research.google.com/github/IndraniMandal/New-Revisions/blob/main/Data_Manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Manipulation
# Pandas supports 1-D (Series), 2-D (DataFrame), and 3-D (Panel) data structures. Here we cover DataFrames because they most closely resemble the kind of data tables data scientists mostly look at.
#
# The advantage of Pandas is that it stores the data together with its metadata.
#
# The most often used meta data with Pandas are the column names and the index.

# %% [markdown]
# The following data and part of code was taken from a [Data Carpentry workshop](https://swcarpentry.github.io/python-novice-gapminder/08-data-frames/index.html).

# %% [markdown]
# ## Load Data

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/IndraniMandal/ds-assets/main/assets/gapminder_gdp_europe.csv')
data.head()
# Out:
#                   country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0                 Albania     1601.056136     1942.284244     2312.888958
# 1                 Austria     6137.076492     8842.598030    10750.721110
# 2                 Belgium     8343.105127     9714.960623    10991.206760
# 3  Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# 4                Bulgaria     2444.286648     3008.670727     4254.337839
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     2760.196931     3313.422188     3533.003910     3630.880722
# 1    12834.602400    16661.625600    19749.422300    21597.083620
# 2    13149.041190    16672.143560    19117.974480    20979.845890
# 3     2172.352423     2860.169750     3528.481305     4126.613157
# 4     5577.002800     6597.494398     7612.240438     8224.191647
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# ...

# %%
data.shape
# Out:
# (30, 13)

# %% [markdown]
# # Dataframe Parts

# %%
data.columns
# Out:
# Index(['country', 'gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962',
#        'gdpPercap_1967', 'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982',
#        'gdpPercap_1987', 'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002',
#        'gdpPercap_2007'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %%
data.values
# Out:
# array([['Albania', 1601.056136, 1942.284244, 2312.888958, 2760.196931,
#         3313.422188, 3533.00391, 3630.880722, 3738.932735, 2497.437901,
#         3193.054604, 4604.211737, 5937.029526],
#        ['Austria', 6137.076492, 8842.59803, 10750.72111, 12834.6024,
#         16661.6256, 19749.4223, 21597.08362, 23687.82607, 27042.01868,
#         29095.92066, 32417.60769, 36126.4927],
#        ['Belgium', 8343.105127, 9714.960623, 10991.20676, 13149.04119,
#         16672.14356, 19117.97448, 20979.84589, 22525.56308, 25575.57069,
#         27561.19663, 30485.88375, 33692.60508],
#        ['Bosnia and Herzegovina', 973.5331948, 1353.989176, 1709.683679,
#         2172.352423, 2860.16975, 3528.481305, 4126.613157, 4314.114757,
#         2546.781445, 4766.355904, 6018.975239, 7446.298803],
#        ['Bulgaria', 2444.286648, 3008.670727, 4254.337839, 5577.0028,
#         6597.494398, 7612.240438, 8224.191647, 8239.854824, 6302.623438,
#         5970.38876, 7696.777725, 10680.79282],
# ...

# %%
data.set_index('country')
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
data
# Out:
#                    country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0                  Albania     1601.056136     1942.284244     2312.888958
# 1                  Austria     6137.076492     8842.598030    10750.721110
# 2                  Belgium     8343.105127     9714.960623    10991.206760
# 3   Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# 4                 Bulgaria     2444.286648     3008.670727     4254.337839
# 5                  Croatia     3119.236520     4338.231617     5477.890018
# 6           Czech Republic     6876.140250     8256.343918    10136.867130
# 7                  Denmark     9692.385245    11099.659350    13583.313510
# 8                  Finland     6424.519071     7545.415386     9371.842561
# 9                   France     7029.809327     8662.834898    10560.485530
# 10                 Germany     7144.114393    10187.826650    12902.462910
# ...

# %%
df = data.set_index('country')
df
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
data.set_index('country', inplace =True)
data.head()
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
#
#                         gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Albania                    2760.196931     3313.422188     3533.003910
# Austria                   12834.602400    16661.625600    19749.422300
# Belgium                   13149.041190    16672.143560    19117.974480
# Bosnia and Herzegovina     2172.352423     2860.169750     3528.481305
# Bulgaria                   5577.002800     6597.494398     7612.240438
#
#                         gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# country
# ...

# %% [markdown]
# #Indexing and Slicing
# For array-style indexing Pandas uses the **loc**, **iloc**, and **ix** indexers.
#
# To access a value at the position $[i,j]$ of a DataFrame, we have two options, depending on what is the meaning of $i$ in use. Remember that a DataFrame provides an index as a way to identify the rows of the table; a row, then, has a position inside the table as well as a label, which uniquely identifies its entry in the DataFrame.
#
# Using the **iloc** indexer, we can index the underlying array as if it is a simple array using row and column integer values (hence the i in iloc). The DataFrame index and column labels are maintained in the result:

# %% [markdown]
# We use `DataFrame.iloc[..., ...]` to select values by their (entry) position

# %%
data.iloc[:2 ,1:4]
# Out:
#          gdpPercap_1957  gdpPercap_1962  gdpPercap_1967
# country
# Albania     1942.284244     2312.888958     2760.196931
# Austria     8842.598030    10750.721110    12834.602400

# %%
data.loc[: 'Austria','gdpPercap_1957': 'gdpPercap_1967' ]
# Out:
#          gdpPercap_1957  gdpPercap_1962  gdpPercap_1967
# country
# Albania     1942.284244     2312.888958     2760.196931
# Austria     8842.598030    10750.721110    12834.602400

# %% [markdown]
# Notice that when slicing with an explicit index (i.e.,` data.loc['a':'c']`), the final index is included in the slice, while when slicing with an implicit index (i.e., `data.iloc[0:2]`), the final index is excluded from the slice.
#
# The indexer **ix** allows the mix of integer and explicit indexing.

# %% [markdown]
# We can specify location by row and/or column name.

# %%
data.loc["Albania", "gdpPercap_1952"]
# Out:
# 1601.056136

# %%
data.loc[['Spain','France'], ['gdpPercap_1962', 'gdpPercap_1972']]
# Out:
#          gdpPercap_1962  gdpPercap_1972
# country
# Spain       5693.843879     10638.75131
# France     10560.485530     16107.19171

# %% [markdown]
# We use `:` on its own to mean all columns or all rows

# %%
data.loc["Albania", :]
# Out:
# gdpPercap_1952    1601.056136
# gdpPercap_1957    1942.284244
# gdpPercap_1962    2312.888958
# gdpPercap_1967    2760.196931
# gdpPercap_1972    3313.422188
# gdpPercap_1977    3533.003910
# gdpPercap_1982    3630.880722
# gdpPercap_1987    3738.932735
# gdpPercap_1992    2497.437901
# gdpPercap_1997    3193.054604
# gdpPercap_2002    4604.211737
# gdpPercap_2007    5937.029526
# Name: Albania, dtype: float64

# %% [markdown]
# Select multiple columns or rows using DataFrame.loc and a named slice

# %%
data.loc['Italy':'Poland', 'gdpPercap_1962':'gdpPercap_1972']
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy           8243.582340    10022.401310    12269.273780
# Montenegro      4649.593785     5907.850937     7778.414017
# Netherlands    12790.849560    15363.251360    18794.745670
# Norway         13450.401510    16361.876470    18965.055510
# Poland          5338.752143     6557.152776     8006.506993

# %% [markdown]
# In the above code, we discover that slicing using `loc` is **inclusive at both ends**, which differs from slicing using `iloc`, where slicing indicates everything up to but not including the final index.

# %% [markdown]
# #Use comparisons to select data based on value
# * Comparison is applied element by element.
# * Returns a similarly-shaped dataframe of `True` and `False`.

# %%
# Use a subset of data to keep output readable.
subset = data.loc['Italy':'Poland', 'gdpPercap_1962':'gdpPercap_1972']
subset
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy           8243.582340    10022.401310    12269.273780
# Montenegro      4649.593785     5907.850937     7778.414017
# Netherlands    12790.849560    15363.251360    18794.745670
# Norway         13450.401510    16361.876470    18965.055510
# Poland          5338.752143     6557.152776     8006.506993

# %%
# Which values were greater than 10000 ?
subset > 10000
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy                 False            True            True
# Montenegro            False           False           False
# Netherlands            True            True            True
# Norway                 True            True            True
# Poland                False           False           False

# %% [markdown]
# We can use relational and boolean expressions when selecting data from a dataframe.

# %%
data.gdpPercap_1952 > 10000
# Out:
# country
# Albania                   False
# Austria                   False
# Belgium                   False
# Bosnia and Herzegovina    False
# Bulgaria                  False
# Croatia                   False
# Czech Republic            False
# Denmark                   False
# Finland                   False
# France                    False
# Germany                   False
# Greece                    False
# Hungary                   False
# Iceland                   False
# Ireland                   False
# Italy                     False
# Montenegro                False
# Netherlands               False
# Norway                     True
# Poland                    False
# Portugal                  False
# Romania                   False
# Serbia                    False
# Slovak Republic           False
# Slovenia                  False
# Spain                     False
# Sweden                    False
# Switzerland                True
# Turkey                    False
# ...

# %%
data[data.gdpPercap_1952 > 10000]
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Norway          10095.42172     11653.97304     13450.40151     16361.87647
# Switzerland     14734.23275     17909.48973     20431.09270     22966.14432
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Norway          18965.05551     23311.34939     26298.63531     31540.97480
# Switzerland     27195.11304     26982.29052     28397.71512     30281.70459
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Norway          33965.66115     41283.16433     44683.97525     49357.19017
# Switzerland     31871.53030     32135.32301     34480.95771     37506.41907

# %%
data[data.gdpPercap_1952 > 10000].gdpPercap_2007
# Out:
# country
# Norway         49357.19017
# Switzerland    37506.41907
# Name: gdpPercap_2007, dtype: float64

# %%
# Which countries had a GDP >10000 in 1952?
data[data.gdpPercap_1952 > 10000]
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Norway          10095.42172     11653.97304     13450.40151     16361.87647
# Switzerland     14734.23275     17909.48973     20431.09270     22966.14432
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Norway          18965.05551     23311.34939     26298.63531     31540.97480
# Switzerland     27195.11304     26982.29052     28397.71512     30281.70459
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Norway          33965.66115     41283.16433     44683.97525     49357.19017
# Switzerland     31871.53030     32135.32301     34480.95771     37506.41907

# %% [markdown]
# ## Accessing attribute values for rows for which the equality holds

# %%
# What is the 2007 GDP of those countries that had a GDP >10000 in 1952?
data[data.gdpPercap_1952 > 10000].loc[: , ['gdpPercap_1962', 'gdpPercap_2007']]
# Out:
#              gdpPercap_1962  gdpPercap_2007
# country
# Norway          13450.40151     49357.19017
# Switzerland     20431.09270     37506.41907

# %%
# Which countries had a GDP greater than 10000 in 1962 and a GDP greater than 35,000 in 2007?
data[(data.gdpPercap_1962 > 10000) & (data.gdpPercap_2007 > 35000)]
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Austria         6137.076492     8842.598030     10750.72111     12834.60240
# Denmark         9692.385245    11099.659350     13583.31351     15937.21123
# Iceland         7267.688428     9244.001412     10350.15906     13319.89568
# Netherlands     8941.571858    11276.193440     12790.84956     15363.25136
# Norway         10095.421720    11653.973040     13450.40151     16361.87647
# Switzerland    14734.232750    17909.489730     20431.09270     22966.14432
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Austria         16661.62560     19749.42230     21597.08362     23687.82607
# Denmark         18866.20721     20422.90150     21688.04048     25116.17581
# Iceland         15798.06362     19654.96247     23269.60750     26923.20628
# Netherlands     18794.74567     21209.05920     21399.46046     23651.32361
# ...

# %% [markdown]
# # Filtering

# %% [markdown]
# ## Filtering using `isin()`

# %%
data.index.isin(['Italy','Norway'])
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False])

# %% [markdown]
# Any Boolean vector can be used as filter.

# %%
v = data.index.isin(['Italy','Norway'])
data[v]
# Out:
#          gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Italy       4931.404155     6248.656232      8243.58234     10022.40131
# Norway     10095.421720    11653.973040     13450.40151     16361.87647
#
#          gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Italy       12269.27378     14255.98475     16537.48350     19207.23482
# Norway      18965.05551     23311.34939     26298.63531     31540.97480
#
#          gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Italy       22013.64486     24675.02446     27968.09817     28569.71970
# Norway      33965.66115     41283.16433     44683.97525     49357.19017

# %% [markdown]
# ## Mask
# A frame full of Booleans is sometimes called a mask because of how it can be used.

# %%
subset
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy           8243.582340    10022.401310    12269.273780
# Montenegro      4649.593785     5907.850937     7778.414017
# Netherlands    12790.849560    15363.251360    18794.745670
# Norway         13450.401510    16361.876470    18965.055510
# Poland          5338.752143     6557.152776     8006.506993

# %%
subset > 10000
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy                 False            True            True
# Montenegro            False           False           False
# Netherlands            True            True            True
# Norway                 True            True            True
# Poland                False           False           False

# %%
mask = subset > 10000
subset[mask]
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy                   NaN     10022.40131     12269.27378
# Montenegro              NaN             NaN             NaN
# Netherlands     12790.84956     15363.25136     18794.74567
# Norway          13450.40151     16361.87647     18965.05551
# Poland                  NaN             NaN             NaN

# %% [markdown]
# * Get the value where the mask is true, and NaN (Not a Number) where it is false.
# * Useful because NaNs are ignored by operations like max, min, average, etc.

# %%
subset[subset > 10000].describe()
# Out:
#        gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# count        2.000000        3.000000        3.000000
# mean     13120.625535    13915.843047    16676.358320
# std        466.373656     3408.589070     3817.597015
# min      12790.849560    10022.401310    12269.273780
# 25%      12955.737548    12692.826335    15532.009725
# 50%      13120.625535    15363.251360    18794.745670
# 75%      13285.513522    15862.563915    18879.900590
# max      13450.401510    16361.876470    18965.055510

# %% [markdown]
# #Group By: split-apply-combine
# Pandas vectorizing methods and grouping operations are features that provide users much flexibility to analyse their data.
#
# For instance, let’s say we want to have a clearer view on how the European countries split themselves according to their GDP.
#
# 1. We may have a glance by splitting the countries in two groups during the years surveyed, those who presented a GDP higher than the European average and those with a lower GDP.
# 2. We then estimate a wealthy score based on the historical (from 1962 to 2007) values, where we account how many times a country has participated in the groups of lower or higher GDP

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %%
mask_higher = data > data.mean()
wealth_score = mask_higher.aggregate('sum', axis=1) / len(data.columns)
wealth_score
# Out:
# country
# Albania                   0.000000
# Austria                   1.000000
# Belgium                   1.000000
# Bosnia and Herzegovina    0.000000
# Bulgaria                  0.000000
# Croatia                   0.000000
# Czech Republic            0.500000
# Denmark                   1.000000
# Finland                   1.000000
# France                    1.000000
# Germany                   1.000000
# Greece                    0.333333
# Hungary                   0.000000
# Iceland                   1.000000
# Ireland                   0.333333
# Italy                     0.500000
# Montenegro                0.000000
# Netherlands               1.000000
# Norway                    1.000000
# Poland                    0.000000
# Portugal                  0.000000
# Romania                   0.000000
# Serbia                    0.000000
# Slovak Republic           0.000000
# Slovenia                  0.333333
# Spain                     0.333333
# ...

# %% [markdown]
# Finally, for each group in the `wealth_score` table, we sum their (financial) contribution across the years surveyed using chained methods

# %%
data.groupby(wealth_score).sum()
# Out:
#           gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# 0.000000    36916.854200    46110.918793    56850.065437    71324.848786
# 0.333333    16790.046878    20942.456800    25744.935321    33567.667670
# 0.500000    11807.544405    14505.000150    18380.449470    21421.846200
# 1.000000   104317.277560   127332.008735   149989.154201   178000.350040
#
#           gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# 0.000000    88569.346898   104459.358438   113553.768507   119649.599409
# 0.333333    45277.839976    53860.456750    59679.634020    64436.912960
# 0.500000    25377.727380    29056.145370    31914.712050    35517.678220
# 1.000000   215162.343140   241143.412730   263388.781960   296825.131210
#
#           gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# 0.000000    92380.047256   103772.937598   118590.929863   149577.357928
# 0.333333    67918.093220    80876.051580   102086.795210   122803.729520
# ...
