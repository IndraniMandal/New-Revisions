# %% [markdown]
# <a href="https://colab.research.google.com/github/IndraniMandal/New-Revisions/blob/main/Loading_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Pipeline
# Data pipeline defines the work flow of data processing.
#
# ## Data source
# Data come from various souces like Analytics data (user behavior data), Transactional data (data from sales and product records), 3rd party data, government data, data from web scrapping, etc.
#
# ## Data Ingestion/Collection
# The data is then integrated from these different sources and entering it into the data pipeline.
#
# ## Data processing
# The processing layer transforms the data into a consumable state. This process involves data validation, clean-up, normalization, transformation, and enrichment.

# %% [markdown]
# ![Data pipeline.png](data:image/png;base64,...)

# %% [markdown]
# Picture credit: [A Guide to Data Pipelines](https://www.striim.com/blog/guide-to-data-pipelines/)

# %% [markdown]
# ## Data Consumption
# The data is now ready for comsumption for advanced analytics and machine learning. We make sense of the data by visualizing the data and performing exploratory analysis. We can perform predictive analytics by building models. Models learn from the data provided and can be used for making predictions about the unknown.

# %% [markdown]
# # Activity 1
# <font color = 'red'>
# What are some different sources of data you can think of? List them under.

# %% [markdown]
# # Machine Learning Pipeline
# In this phase we train the model using the data we have collected and test the model performance.

# %% [markdown]
# ![machine-learning-pipeline.png](data:image/png;base64,...)

# %% [markdown]
# Picture credit: [Machine learning Pipeline Deployment and Architecture](https://www.xenonstack.com/blog/machine-learning-pipeline)

# %% [markdown]
# ## Load the Data

# %% [markdown]
# ### Connecting to my Github

# %%
# !test -e ds-assets && cd ds-assets && git pull && cd ..
# !test ! -e ds-assets && git clone https://github.com/IndraniMandal/ds-assets.git
home = "ds-assets/assets/" 
import sys
sys.path.append(home)
# Out:
# Cloning into 'ds-assets'...
# remote: Enumerating objects: 176, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 176 (delta 3), reused 2 (delta 0), pack-reused 164
# Receiving objects: 100% (176/176), 9.35 MiB | 13.88 MiB/s, done.
# Resolving deltas: 100% (63/63), done.

# %% [markdown]
# You can direct access the notebooks my Github. You can access data from there or any other resources shared there.
#
# ![githubtocolab.png](data:image/png;base64,...)

# %% [markdown]
# Picture credit: [How to use Google Colab with GitHub via Google Drive](https://medium.com/analytics-vidhya/how-to-use-google-colab-with-github-via-google-drive-68efb23a42d)

# %%
from google.colab import files
import io

# %% [markdown]
# Choose a readable file such as a comma-separated values file, (csv for short), to be displayed in pandas.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-319dc7aa-1a8d-4c5b-a88d-36f16d83cdfa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-319dc7aa-1a8d-4c5b-a88d-36f16d83cdfa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Instantiates the uploaded file as a readable csv file. The name of the file has to be exactly the same or else it will cause an error.

# %%
uploaded = io.BytesIO(uploaded['PancreaticCancer2020.csv'])

# %%
uploaded

# %% [markdown]
# Convert the uploaded file into a readable dataframe. Dataframes refresent the uploaded file into a tabular format and offer function operations on them.

# %% [markdown]
# # Activity 2
# <font color = 'red'>
# Upload a dataset of your choosing from your computer.

# %%
import pandas as pd
cancer_df = pd.read_csv(uploaded)
cancer_df.head()
# Out:
#   sample_id patient_cohort sample_origin  age sex  diagnosis stage  \
# 0        S1        Cohort1          BPTB   33   F          1   NaN
# 1       S10        Cohort1          BPTB   81   F          1   NaN
# 2      S100        Cohort2          BPTB   51   M          1   NaN
# 3      S101        Cohort2          BPTB   61   M          1   NaN
# 4      S102        Cohort2          BPTB   62   M          1   NaN
#
#   benign_sample_diagnosis  plasma_CA19_9  creatinine     LYVE1      REG1B  \
# 0                     NaN           11.7     1.83222  0.893219   52.94884
# 1                     NaN            NaN     0.97266  2.037585   94.46703
# 2                     NaN            7.0     0.78039  0.145589  102.36600
# 3                     NaN            8.0     0.70122  0.002805   60.57900
# 4                     NaN            9.0     0.21489  0.000860   65.54000
#
#          TFF1     REG1A
# 0  654.282174  1262.000
# 1  209.488250   228.407
# 2  461.141000       NaN
# ...

# %%
cancer_df.tail(10)
# Out:
#     sample_id patient_cohort sample_origin  age sex  diagnosis stage  \
# 580      S522        Cohort1          BPTB   46   M          3    IV
# 581      S529        Cohort1          BPTB   61   F          3    IV
# 582      S535        Cohort2          BPTB   58   F          3    IV
# 583      S539        Cohort2          BPTB   84   M          3    IV
# 584      S548        Cohort2          BPTB   66   M          3    IV
# 585      S549        Cohort2          BPTB   68   M          3    IV
# 586      S558        Cohort2          BPTB   71   F          3    IV
# 587      S560        Cohort2          BPTB   63   M          3    IV
# 588      S583        Cohort2          BPTB   75   F          3    IV
# 589      S590        Cohort1          BPTB   74   M          3    IV
#
#     benign_sample_diagnosis  plasma_CA19_9  creatinine      LYVE1       REG1B  \
# 580                     NaN            NaN     0.75777  10.578610  206.526460
# ...

# %% [markdown]
# ### Loading data from Github

# %% [markdown]
# You can directly access data stored in a Github Repo. This is more efficent than directly uploading file from local. Additionally, sharing data and notebooks are much easear through Github repos.

# %% [markdown]
# Always access the Raw file from Github. If you use the link to Github's rendering of the dataset you will get an error.
#
# ![githubraw.PNG](data:image/png;base64,...)

# %%
url = "https://raw.githubusercontent.com/IndraniMandal/ds-assets/main/assets/abalone.csv"
df = pd.read_csv(url)
df.head()
# Out:
#   sex  length  diameter  height  whole weight  shucked weight  viscera weight  \
# 0   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 1   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
# 2   I   0.425     0.300   0.095        0.3515          0.1410          0.0775
# 3   F   0.530     0.415   0.150        0.7775          0.2370          0.1415
# 4   F   0.545     0.425   0.125        0.7680          0.2940          0.1495
#
#    shell weight
# 0         0.210
# 1         0.055
# 2         0.120
# 3         0.330
# 4         0.260

# %% [markdown]
# # Activity 3
# <font color = 'red'>
# Load and display the head of the 'iris' dataset from my GitHub repo.

# %% [markdown]
# ### Loading data from Google Drive for Colabs
#
# You can access datasets saved in a Google Drive from Google Colab. You have to give permission to Google Colab to access your Google Drive.
#
# You can connect to your Google Drive via the code block below or via the "Mount Drive" button that comes with Google Colabs.
#
# ![gdrivelocation.PNG](data:image/png;base64,...)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
gdrive = pd.read_csv("/content/drive/MyDrive/Datasets/wdbc.csv")
gdrive.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-48d775ad51cd> in <module>
# ----> 1 gdrive = pd.read_csv("/content/drive/MyDrive/Datasets/wdbc.csv")
#       2 gdrive.head()
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# ###Kaggle
# ####Local drive set up and implementation

# %% [markdown]
# We can upload data from Kaggle.com as well. You can use linux based commands to install necessary library, make directory and assign necessary permissions. It requires uploading the kaggle.json file to the notebook on restart.
#
# kaggle.json files are obtained from Kaggle.com under user settings.

# %% [markdown]
# Step 1:
#
# ![kaggle1.PNG](data:image/png;base64,...)
#
# Step 2:
#
# ![kaggle2.PNG](data:image/png;base64,...)
#
# Step 3:
#
# ![kaggle3.PNG](data:image/png;base64,...)

# %% [markdown]
# Once you press "Create New API Token," the kaggle.json file should be downloaded. Note that your API token only works for YOUR account, so it is not necessarily a good idea to share this with others. Keep it somewhere safe, as it can be used many times!
#
# Before we can use the kaggle.json, we must first install the library needed. Because Google Colab is UNIX-based, we can use UNIX commands to install libraries directly into this notebook. Note that anything installed and downloaded into a notebook is deleted once reset, so it needs to be done each time.

# %%
! pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# Once the libraries are installed, a directory (more commonly known as a "folder") should be made to store the kaggle.json file you downloaded earlier.

# %%
! mkdir ~/.kaggle

# %% [markdown]
# For the notebook to have access to the kaggle.json file, it first must be uploaded to the notebook. This can be done by using the "Upload to session storage" button that comes with Google Colabs.

# %% [markdown]
# ![uploadlocation.PNG](data:image/png;base64,...)

# %% [markdown]
# Once the kaggle.json file is visible below "sample_data," it can be copied to the directory you made just recently, where the libraries that have been installed can properly use it. After being copied, it is given the necessary permissions to be used.

# %%
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Once everthing is set up, you can download datasets directly from Kaggle.com using this command:
# ```
# ! kaggle datasets download [url of dataset]
# ```
#
# The url used is the part of the url directly after "dataset/" in the url of a dataset.
#
# Example:
#
# https://www.kaggle.com/datasets/<font color = 'red'>johnjdavisiv/urinary-biomarkers-for-pancreatic-cancer
#
# ```
# ! kaggle datasets download johnjdavisiv/urinary-biomarkers-for-pancreatic-cancer
# ```

# %%
! kaggle datasets download johnjdavisiv/urinary-biomarkers-for-pancreatic-cancer
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.8/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.8/dist-packages/kaggle/api/kaggle_api_extended.py", line 164, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %% [markdown]
# Once the file is downloaded, you might notice that the file is in a zip file. You can't directly unzip a file in a notebook, so you need another UNIX command to unzip it.
#
# ```
# !unzip [path to file]
# ```
#
# The path to a file can be found by right-clicking on said file and and then pressing "Copy path." The path should be copied to your clipboard, so it can be easily pasted.

# %%
# !unzip /content/urinary-biomarkers-for-pancreatic-cancer.zip
# Out:
# unzip:  cannot find or open /content/urinary-biomarkers-for-pancreatic-cancer.zip, /content/urinary-biomarkers-for-pancreatic-cancer.zip.zip or /content/urinary-biomarkers-for-pancreatic-cancer.zip.ZIP.
# rm: cannot remove '/content/urinary-biomarkers-for-pancreatic-cancer.zip': No such file or directory

# %% [markdown]
# Once the file is unzipped, you should see the dataset(s) should be added to your files once you refresh the files tab.
#
# The next block of code deletes the zipped file, as it is no longer needed. This is completely optional, but having a neat notebook is a good work habit.

# %%
# !rm /content/urinary-biomarkers-for-pancreatic-cancer.zip

# %% [markdown]
# ####Google drive set up and implementation
# The same process for the previously mentioned Kaggle method can be applied but this time, the kaggle.json can be accessed from your Google Drive. This makes it so you do not have to upload your kaggle.json file each time the runtime is restarted.
#
#  The first two steps are the same as the previous method.

# %%
! pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %% [markdown]
# This time, you directly upload your kaggle.json file directly into your Google Drive. Do NOT place it into any other directory/file.
#
# After it is placed in your Google Drive, mount Google Drive to your notebook if your runtime was restarted or was disconnected.
#
# Instead of copying from the notebook where the file is prone to deletion, it now copies the file directly from the Google Drive, where it does not get deleted.

# %%
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/kaggle.json

# %% [markdown]
# The downloading and unzipping of the file is the same as earlier.

# %%
! kaggle datasets download johnjdavisiv/urinary-biomarkers-for-pancreatic-cancer
# Out:
# ...
#   0% 0.00/18.0k [00:00<?, ?B/s]
# 100% 18.0k/18.0k [00:00<00:00, 22.8MB/s]

# %%
# !unzip /content/urinary-biomarkers-for-pancreatic-cancer.zip
# !rm /content/urinary-biomarkers-for-pancreatic-cancer.zip
# Out:
# Archive:  /content/urinary-biomarkers-for-pancreatic-cancer.zip
#   inflating: Debernardi et al 2020 data.csv
#   inflating: Debernardi et al 2020 documentation.csv

# %% [markdown]
# And with that, we can display the csv we downloaded from Kaggle.

# %%
kaggle = pd.read_csv("/content/Debernardi et al 2020 data.csv")
kaggle.head()
# Out:
#   sample_id patient_cohort sample_origin  age sex  diagnosis stage  \
# 0        S1        Cohort1          BPTB   33   F          1   NaN
# 1       S10        Cohort1          BPTB   81   F          1   NaN
# 2      S100        Cohort2          BPTB   51   M          1   NaN
# 3      S101        Cohort2          BPTB   61   M          1   NaN
# 4      S102        Cohort2          BPTB   62   M          1   NaN
#
#   benign_sample_diagnosis  plasma_CA19_9  creatinine     LYVE1      REG1B  \
# 0                     NaN           11.7     1.83222  0.893219   52.94884
# 1                     NaN            NaN     0.97266  2.037585   94.46703
# 2                     NaN            7.0     0.78039  0.145589  102.36600
# 3                     NaN            8.0     0.70122  0.002805   60.57900
# 4                     NaN            9.0     0.21489  0.000860   65.54000
#
#          TFF1     REG1A
# 0  654.282174  1262.000
# 1  209.488250   228.407
# 2  461.141000       NaN
# ...

# %% [markdown]
# # Activity 4
# <font color = 'red'>
# Repeat the process above to load the dataset on Pancreatic cancer into your copy of the Google Colab notebook using the Google Drive method. Ask for help if you get stuck.

# %%
iris = pd.read_csv("https://raw.githubusercontent.com/IndraniMandal/ds-assets/main/assets/iris.csv")
iris.head()
# Out:
#    id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0   1           5.1          3.5           1.4          0.2  setosa
# 1   2           4.9          3.0           1.4          0.2  setosa
# 2   3           4.7          3.2           1.3          0.2  setosa
# 3   4           4.6          3.1           1.5          0.2  setosa
# 4   5           5.0          3.6           1.4          0.2  setosa

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.isnull().sum()
# Out:
# id              0
# Sepal.Length    0
# Sepal.Width     0
# Petal.Length    0
# Petal.Width     0
# Species         0
# dtype: int64

# %%
iris['Sepal.Length'].max()
# Out:
# 7.9

# %%
iris['Sepal.Width'].min()
# Out:
# 2.0

# %% [markdown]
# # Urinary biomarkers for pancreatic cancer Dataset
# ### About Dataset
# This is a [dataset](https://www.kaggle.com/datasets/johnjdavisiv/urinary-biomarkers-for-pancreatic-cancer?resource=download) from an open-access paper published December 10, 2020. The paper and the full dataset are open-access (CC-BY), so please give attribution to the original authors in your work.
#
# ###Background
# Pancreatic cancer is an extremely deadly type of cancer. Once diagnosed, the five-year survival rate is less than 10%. However, if pancreatic cancer is caught early, the odds of surviving are much better. Unfortunately, many cases of pancreatic cancer show no symptoms until the cancer has spread throughout the body. A diagnostic test to identify people with pancreatic cancer could be enormously helpful.
#
# ###Background
# Pancreatic cancer is an extremely deadly type of cancer. Once diagnosed, the five-year survival rate is less than 10%. However, if pancreatic cancer is caught early, the odds of surviving are much better. Unfortunately, many cases of pancreatic cancer show no symptoms until the cancer has spread throughout the body. A diagnostic test to identify people with pancreatic cancer could be enormously helpful.
#
# ###The paper
# In a paper by Silvana Debernardi and colleagues, published this year in the journal PLOS Medicine, a multi-national team of researchers sought to develop an accurate diagnostic test for the most common type of pancreatic cancer, called pancreatic ductal adenocarcinoma or PDAC. They gathered a series of biomarkers from the urine of three groups of patients:
#
# ###Healthy controls
# * Patients with non-cancerous pancreatic conditions, like chronic pancreatitis
# * Patients with pancreatic ductal adenocarcinoma
#
# When possible, these patients were age- and sex-matched. The goal was to develop an accurate way to identify patients with pancreatic cancer.
#
# ###The data
# The key features are four urinary biomarkers: creatinine, LYVE1, REG1B, and TFF1.
#
# * Creatinine is a protein that is often used as an indicator of kidney function.
# * YVLE1 is lymphatic vessel endothelial hyaluronan receptor 1, a protein that may play a role in tumor metastasis
# * REG1B is a protein that may be associated with pancreas regeneration
# * TFF1 is trefoil factor 1, which may be related to regeneration and repair of the urinary tract
#
# **Age** and **sex**, both included in the dataset, may also play a role in who gets pancreatic cancer. The dataset includes a few other biomarkers as well, but these were not measured in all patients (they were collected partly to measure how various blood biomarkers compared to urine biomarkers).
#
# I have not changed any of the data from the paper, other than renaming the columns for easy importing and use. The file *Debernardi et al 2020 data.csv* contains the raw data, while the file *Debernardi et al 2020 documentation.csv *contains a detailed documentation of what each column represents (as well as the original column names from the paper).
#
# ###Prediction task
# The goal in this dataset is predicting diagnosis, and more specifically, differentiating between 3 (pancreatic cancer) versus 2 (non-cancerous pancreas condition) and 1 (healthy). The dataset includes information on stage of pancreatic cancer, and diagnosis for non-cancerous patients, but remember—these won't be available to a predictive model. The goal, after all, is to predict the presence of disease before it's diagnosed, not after!

# %% [markdown]
# ##Load the Data from Kaggle

# %%
kaggle = pd.read_csv("/content/Debernardi et al 2020 data.csv")
kaggle.head()
# Out:
#   sample_id patient_cohort sample_origin  age sex  diagnosis stage  \
# 0        S1        Cohort1          BPTB   33   F          1   NaN
# 1       S10        Cohort1          BPTB   81   F          1   NaN
# 2      S100        Cohort2          BPTB   51   M          1   NaN
# 3      S101        Cohort2          BPTB   61   M          1   NaN
# 4      S102        Cohort2          BPTB   62   M          1   NaN
#
#   benign_sample_diagnosis  plasma_CA19_9  creatinine     LYVE1      REG1B  \
# 0                     NaN           11.7     1.83222  0.893219   52.94884
# 1                     NaN            NaN     0.97266  2.037585   94.46703
# 2                     NaN            7.0     0.78039  0.145589  102.36600
# 3                     NaN            8.0     0.70122  0.002805   60.57900
# 4                     NaN            9.0     0.21489  0.000860   65.54000
#
#          TFF1     REG1A
# 0  654.282174  1262.000
# 1  209.488250   228.407
# 2  461.141000       NaN
# ...

# %% [markdown]
# Note that some columns have NaN values. We will have to think about handling missing data in the future. In the meantime, let's save the original copy in the Google Drive.

# %%
cancer_df = kaggle.copy()
cancer_df
# Out:
#     sample_id patient_cohort sample_origin  age sex  diagnosis stage  \
# 0          S1        Cohort1          BPTB   33   F          1   NaN
# 1         S10        Cohort1          BPTB   81   F          1   NaN
# 2        S100        Cohort2          BPTB   51   M          1   NaN
# 3        S101        Cohort2          BPTB   61   M          1   NaN
# 4        S102        Cohort2          BPTB   62   M          1   NaN
# ..        ...            ...           ...  ...  ..        ...   ...
# 585      S549        Cohort2          BPTB   68   M          3    IV
# 586      S558        Cohort2          BPTB   71   F          3    IV
# 587      S560        Cohort2          BPTB   63   M          3    IV
# 588      S583        Cohort2          BPTB   75   F          3    IV
# 589      S590        Cohort1          BPTB   74   M          3    IV
#
#     benign_sample_diagnosis  plasma_CA19_9  creatinine     LYVE1       REG1B  \
# ...

# %% [markdown]
# # Activity 5
# <font color = 'red'>
# Answer the following questions:
# 1. How many **rows** and **columns** are there?
# 2. Are there any **missing values** in the dataset?
# 3. What is the **maximun** and **minimun** age of the patients?
# 4. How many Male and Female patients are there?

# %%
cancer_df.shape
# Out:
# (590, 14)

# %%
cancer_df.isnull().sum()
# Out:
# sample_id                    0
# patient_cohort               0
# sample_origin                0
# age                          0
# sex                          0
# diagnosis                    0
# stage                      391
# benign_sample_diagnosis    382
# plasma_CA19_9              240
# creatinine                   0
# LYVE1                        0
# REG1B                        0
# TFF1                         0
# REG1A                      284
# dtype: int64

# %%
import numpy as np
for column in cancer_df:
    print('{} has {} % missing values'.format(column,np.round(cancer_df[column].isnull().sum()/len(cancer_df)*100,2)))
# Out:
# sample_id has 0.0 % missing values
# patient_cohort has 0.0 % missing values
# sample_origin has 0.0 % missing values
# age has 0.0 % missing values
# sex has 0.0 % missing values
# diagnosis has 0.0 % missing values
# stage has 66.27 % missing values
# benign_sample_diagnosis has 64.75 % missing values
# plasma_CA19_9 has 40.68 % missing values
# creatinine has 0.0 % missing values
# LYVE1 has 0.0 % missing values
# REG1B has 0.0 % missing values
# TFF1 has 0.0 % missing values
# REG1A has 48.14 % missing values

# %% [markdown]
# Let'a drop some of the features which don't add value to the decission making process like Sample ID  and Patient Cohort.

# %%
cancer_df = cancer_df.drop(['sample_id', 'patient_cohort'], axis = 1)

# %%
cancer_df.age
# Out:
# 0      33
# 1      81
# 2      51
# 3      61
# 4      62
#        ..
# 585    68
# 586    71
# 587    63
# 588    75
# 589    74
# Name: age, Length: 590, dtype: int64

# %%
cancer_df.age.describe()
# Out:
# count    590.000000
# mean      59.079661
# std       13.109520
# min       26.000000
# 25%       50.000000
# 50%       60.000000
# 75%       69.000000
# max       89.000000
# Name: age, dtype: float64

# %%
cancer_df.age.max()
# Out:
# 89

# %%
cancer_df.age.min()
# Out:
# 26

# %%
cancer_df.sex.value_counts()
# Out:
# F    299
# M    291
# Name: sex, dtype: int64
